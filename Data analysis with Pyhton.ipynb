# %% [markdown]
# <h1>DATA ANALYSIS USING PYTHON</h1>

# %% [markdown]
# <h1 id="data_acquisition">Data Acquisition</h1>
# <p>
# There are various formats for a dataset: .csv, .json, .xlsx  etc. The dataset can be stored in different places, on your local machine or sometimes online.<br>
#
# In this section, I will do how to load a dataset into my Jupyter Notebook.<br>
#
# In our case, the Automobile Dataset is an online source, and it is in a CSV (comma separated value) format. Let's use this dataset as an example to practice data reading.
#
# <ul>
#     <li>Data source: <a href="https://www.kaggle.com/datasets/madhankumar789/crop-yield-and-environmental-factors-2014-2023" target="_blank">https://www.kaggle.com/datasets/madhankumar789/crop-yield-and-environmental-factors-2014-2023</a></li>
#     <li>Data type: csv</li>
# </ul>
# The Pandas Library is a useful tool that enables us to read various datasets into a dataframe; my Jupyter notebook platforms have a built-in <b>Pandas Library</b> so that all I need to do is import Pandas without installing.
# </p>

# %% [markdown]
# <b>Import some libraries</b>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# I use <code>pandas.read_csv()</code> function to read the csv file. In the brackets, I put the file path along with a quotation mark so that pandas will read the file into a dataframe from that address. The file path can be either an URL or your local file address.<br>
#
# Because the data does not include headers, I can add an argument <code>headers = None</code> inside the <code>read_csv()</code> method so that pandas will not automatically set the first row as a header.<br>
#
# </p>

# %% [markdown]
# Load the csv in the datframe:

# %%
df=pd.read_csv('crop_yield_dataset.csv')
df.head(10)
# Out:
#        Date  Crop_Type Soil_Type  Soil_pH  Temperature        Humidity  \
# 0  1/1/2014      Wheat     Peaty     5.50          9.440599  80.000000
# 1  1/1/2014       Corn     Loamy     6.50         20.052576  79.947424
# 2  1/1/2014       Rice     Peaty     5.50         12.143099  80.000000
# 3  1/1/2014     Barley     Sandy     6.75         19.751848  80.000000
# 4  1/1/2014    Soybean     Peaty     5.50         16.110395  80.000000
# 5  1/1/2014     Cotton     Sandy     6.75         14.826739  80.000000
# 6  1/1/2014  Sugarcane    Saline     8.00         13.533004  80.000000
# 7  1/1/2014     Tomato      Clay     6.25         18.323272  80.000000
# 8  1/1/2014     Potato     Peaty     5.50         18.895963  80.000000
# 9  1/1/2014  Sunflower     Loamy     6.50         16.865595  80.000000
#
#    Wind_Speed     N     P     K  Crop_Yield  Soil_Quality
# 0   10.956707  60.5  45.0  31.5    0.000000     22.833333
# 1    8.591577  84.0  66.0  50.0  104.871310     66.666667
# ...

# %% [markdown]
# <h3>Add Headers</h3>
# <p>
# Take a look at my dataset. Pandas automatically set the header with an integer starting from 0.
# </p>
# <p>
# To better describe my data, I can introduce a header.
# </p>
# <p>
# Thus, I have to add headers manually.
# </p>
# <p>
# First, I create a list "headers" that include all column names in order.
# Then, I use <code>dataframe.columns = headers</code> to replace the headers with the list I created.
# </p>

# %%
headers=['date','crop_type','soil_type','soil_ph','temperature','humidity','wind_speed','n','p','k','crop_yield','soil_quality']
print('headers/n',headers)
# Out:
# headers/n ['date', 'crop_type', 'soil_type', 'soil_ph', 'temperature', 'humidity', 'wind_speed', 'n', 'p', 'k', 'crop_yield', 'soil_quality']

# %% [markdown]
# I replace headers and recheck our dataframe:

# %%
df.columns=headers
df.head(5)
# Out:
#        date crop_type soil_type  soil_ph  temperature   humidity  wind_speed  \
# 0  1/1/2014     Wheat     Peaty     5.50     9.440599  80.000000   10.956707
# 1  1/1/2014      Corn     Loamy     6.50    20.052576  79.947424    8.591577
# 2  1/1/2014      Rice     Peaty     5.50    12.143099  80.000000    7.227751
# 3  1/1/2014    Barley     Sandy     6.75    19.751848  80.000000    2.682683
# 4  1/1/2014   Soybean     Peaty     5.50    16.110395  80.000000    7.696070
#
#       n     p     k  crop_yield  soil_quality
# 0  60.5  45.0  31.5    0.000000     22.833333
# 1  84.0  66.0  50.0  104.871310     66.666667
# 2  71.5  54.0  38.5    0.000000     27.333333
# 3  50.0  40.0  30.0   58.939796     35.000000
# 4  49.5  45.0  38.5   32.970413     22.166667

# %% [markdown]
# I need to replace the "?" symbol with NaN so the dropna() can remove the missing values:

# %%
df1=df.replace('?',np.nan)

# %%
df=df1.dropna(subset=["crop_yield"], axis=0)
df.head(10)
# Out:
#        date  crop_type soil_type  soil_ph  temperature   humidity  wind_speed  \
# 0  1/1/2014      Wheat     Peaty     5.50     9.440599  80.000000   10.956707
# 1  1/1/2014       Corn     Loamy     6.50    20.052576  79.947424    8.591577
# 2  1/1/2014       Rice     Peaty     5.50    12.143099  80.000000    7.227751
# 3  1/1/2014     Barley     Sandy     6.75    19.751848  80.000000    2.682683
# 4  1/1/2014    Soybean     Peaty     5.50    16.110395  80.000000    7.696070
# 5  1/1/2014     Cotton     Sandy     6.75    14.826739  80.000000   10.366658
# 6  1/1/2014  Sugarcane    Saline     8.00    13.533004  80.000000    9.910484
# 7  1/1/2014     Tomato      Clay     6.25    18.323272  80.000000    8.198084
# 8  1/1/2014     Potato     Peaty     5.50    18.895963  80.000000    6.696707
# 9  1/1/2014  Sunflower     Loamy     6.50    16.865595  80.000000    9.311649
#
#       n     p     k  crop_yield  soil_quality
# 0  60.5  45.0  31.5    0.000000     22.833333
# ...

# %% [markdown]
# <h2>Save Dataset</h2>
# <p>
# Correspondingly, Pandas enables me to save the dataset to csv. By using the <code>dataframe.to_csv()</code> method, I can add the file path and name along with quotation marks in the brackets.
# </p>

# %%
df.to_csv("automobile.csv", index=False)

# %% [markdown]
# <h1 id="basic_insight">Basic Insight of Dataset</h1>
# <p>
# After reading data into Pandas dataframe, it is time for us to explore the dataset.<br>
#
# There are several ways to obtain essential insights of the data to help me better understand my dataset.
#
# </p>

# %% [markdown]
# <h2>Data Types</h2>
# <p>
# Data has a variety of types.<br>
#
# The main types stored in Pandas dataframes are <b>object</b>, <b>float</b>, <b>int</b>, <b>bool</b> and <b>datetime64</b>. In order to better learn about each attribute, it is always good for me to know the data type of each column. In Pandas:
#
# </p>

# %%
df.dtypes
# Out:
# date             object
# crop_type        object
# soil_type        object
# soil_ph         float64
# temperature     float64
# humidity        float64
# wind_speed      float64
# n               float64
# p               float64
# k               float64
# crop_yield      float64
# soil_quality    float64
# dtype: object

# %% [markdown]
# Usw describe function to describe the data

# %% [markdown]
# <h2>Describe</h2>
# If I would like to get a statistical summary of each column e.g. count, column mean value, column standard deviation, etc., I use the describe method:

# %% [markdown]
# This method will provide various summary statistics, excluding NaN (Not a Number) values.

# %%
df.describe()
# Out:
#             soil_ph   temperature      humidity    wind_speed             n  \
# count  36520.000000  36520.000000  36520.000000  36520.000000  36520.000000
# mean       6.602731     23.813996     74.256624     10.020153     66.011035
# std        0.816973      8.920519      6.767587      2.998310     10.886721
# min        5.500000     -3.540176     45.851089     -3.388906     45.000000
# 25%        6.250000     17.168542     69.745252      7.985872     58.500000
# 50%        6.500000     22.902987     77.097013     10.000299     65.000000
# 75%        6.750000     30.254748     80.000000     12.038546     71.500000
# max        8.000000     54.148911     80.000000     22.606078     91.000000
#
#                   p            k    crop_yield  soil_quality
# count  36520.000000  36520.00000  36520.000000  36520.000000
# mean      53.014006     42.01825     26.878480     37.516632
# std        8.812884      8.53781     25.740936     17.703171
# ...

# %% [markdown]
# This shows the statistical summary of all numeric-typed (int, float) columns.
#
# However, what if I would also like to check all the columns including those that are of type object?
#
# I can add an argument include = "all" inside the bracket. Let's try it again.

# %%
df.describe(include = "all")
# Out:
#               date crop_type soil_type       soil_ph   temperature  \
# count        36520     36520     36520  36520.000000  36520.000000
# unique        3652        10         5           NaN           NaN
# top     12/31/2023     Wheat    Saline           NaN           NaN
# freq            10      3652      7361           NaN           NaN
# mean           NaN       NaN       NaN      6.602731     23.813996
# std            NaN       NaN       NaN      0.816973      8.920519
# min            NaN       NaN       NaN      5.500000     -3.540176
# 25%            NaN       NaN       NaN      6.250000     17.168542
# 50%            NaN       NaN       NaN      6.500000     22.902987
# 75%            NaN       NaN       NaN      6.750000     30.254748
# max            NaN       NaN       NaN      8.000000     54.148911
#
#             humidity    wind_speed             n             p            k  \
# count   36520.000000  36520.000000  36520.000000  36520.000000  36520.00000
# ...

# %% [markdown]
# <p>
# Now it provides the statistical summary of all the columns, including object-typed attributes.<br>
#
# I can now see how many unique values there, which one is the top value and the frequency of top value in the object-typed columns.<br>
#
# Some values in the table above show as "NaN". This is because those numbers are not available regarding a particular column type.<br>
#
# </p>

# %% [markdown]
# <h2>Info</h2>
# Another method I can use to check your dataset is:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36520 entries, 0 to 36519
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          36520 non-null  object
#  1   crop_type     36520 non-null  object
#  2   soil_type     36520 non-null  object
#  3   soil_ph       36520 non-null  float64
#  4   temperature   36520 non-null  float64
#  5   humidity      36520 non-null  float64
#  6   wind_speed    36520 non-null  float64
#  7   n             36520 non-null  float64
#  8   p             36520 non-null  float64
#  9   k             36520 non-null  float64
#  10  crop_yield    36520 non-null  float64
#  11  soil_quality  36520 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# It provides a concise summary of your DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %% [markdown]
# <h2 id="identify_handle_missing_values">Identify and handle missing values</h2>
#
# <h3 id="identify_missing_values">Identify missing values</h3>
# <h4>Convert "?" to NaN</h4>
# In the dataset, missing data comes with the question mark "?".
# I replace "?" with NaN (Not a Number), Python's default missing value marker for reasons of computational speed and convenience. Here I use the function:
#  <pre>.replace(A, B, inplace = True) </pre>
# to replace A by B.

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#        date crop_type soil_type  soil_ph  temperature   humidity  wind_speed  \
# 0  1/1/2014     Wheat     Peaty     5.50     9.440599  80.000000   10.956707
# 1  1/1/2014      Corn     Loamy     6.50    20.052576  79.947424    8.591577
# 2  1/1/2014      Rice     Peaty     5.50    12.143099  80.000000    7.227751
# 3  1/1/2014    Barley     Sandy     6.75    19.751848  80.000000    2.682683
# 4  1/1/2014   Soybean     Peaty     5.50    16.110395  80.000000    7.696070
#
#       n     p     k  crop_yield  soil_quality
# 0  60.5  45.0  31.5    0.000000     22.833333
# 1  84.0  66.0  50.0  104.871310     66.666667
# 2  71.5  54.0  38.5    0.000000     27.333333
# 3  50.0  40.0  30.0   58.939796     35.000000
# 4  49.5  45.0  38.5   32.970413     22.166667

# %% [markdown]
# <h4>Evaluating for Missing Data</h4>
#
# The missing values are converted by default. I use the following functions to identify these missing values. There are two methods to detect missing data:
#
# <ol>
#     <li><b>.isnull()</b></li>
#     <li><b>.notnull()</b></li>
# </ol>
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
missing_data=df.isnull()
missing_data.head(5)
# Out:
#     date  crop_type  soil_type  soil_ph  temperature  humidity  wind_speed  \
# 0  False      False      False    False        False     False       False
# 1  False      False      False    False        False     False       False
# 2  False      False      False    False        False     False       False
# 3  False      False      False    False        False     False       False
# 4  False      False      False    False        False     False       False
#
#        n      p      k  crop_yield  soil_quality
# 0  False  False  False       False         False
# 1  False  False  False       False         False
# 2  False  False  False       False         False
# 3  False  False  False       False         False
# 4  False  False  False       False         False

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# <h4>Count missing values in each column</h4>
# <p>
# Using a for loop in Python, I can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the dataset.  In the body of the for loop the method ".value_counts()" counts the number of "True" values.
# </p>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# date
# date
# False    36520
# Name: count, dtype: int64
#
# crop_type
# crop_type
# False    36520
# Name: count, dtype: int64
#
# soil_type
# soil_type
# False    36520
# Name: count, dtype: int64
#
# soil_ph
# soil_ph
# False    36520
# Name: count, dtype: int64
#
# temperature
# temperature
# False    36520
# Name: count, dtype: int64
#
# humidity
# humidity
# False    36520
# Name: count, dtype: int64
#
# wind_speed
# wind_speed
# False    36520
# Name: count, dtype: int64
#
# n
# n
# False    36520
# Name: count, dtype: int64
#
# p
# p
# False    36520
# Name: count, dtype: int64
#
# k
# k
# False    36520
# Name: count, dtype: int64
#
# crop_yield
# crop_yield
# False    36520
# Name: count, dtype: int64
#
# soil_quality
# soil_quality
# False    36520
# Name: count, dtype: int64

# %% [markdown]
# Based on the summary above, each column has no missing data. So, don't need to deal any missing data.

# %% [markdown]
# Check the crop yield which is greater than zero.

# %%
df = df[df['crop_yield'] > 0]
df.head(5)
# Out:
#        date crop_type soil_type  soil_ph  temperature   humidity  wind_speed  \
# 1  1/1/2014      Corn     Loamy     6.50    20.052576  79.947424    8.591577
# 3  1/1/2014    Barley     Sandy     6.75    19.751848  80.000000    2.682683
# 4  1/1/2014   Soybean     Peaty     5.50    16.110395  80.000000    7.696070
# 5  1/1/2014    Cotton     Sandy     6.75    14.826739  80.000000   10.366658
# 7  1/1/2014    Tomato      Clay     6.25    18.323272  80.000000    8.198084
#
#       n     p     k  crop_yield  soil_quality
# 1  84.0  66.0  50.0  104.871310     66.666667
# 3  50.0  40.0  30.0   58.939796     35.000000
# 4  49.5  45.0  38.5   32.970413     22.166667
# 5  55.0  44.0  36.0   29.356115     39.375000
# 7  60.0  45.0  40.0   22.221375     42.291667

# %% [markdown]
# Use the Pandas to_datetime function convert the date into standard date format which helps in latter analysis.

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.head(5)
# Out:
#         date crop_type soil_type  soil_ph  temperature   humidity  wind_speed  \
# 1 2014-01-01      Corn     Loamy     6.50    20.052576  79.947424    8.591577
# 3 2014-01-01    Barley     Sandy     6.75    19.751848  80.000000    2.682683
# 4 2014-01-01   Soybean     Peaty     5.50    16.110395  80.000000    7.696070
# 5 2014-01-01    Cotton     Sandy     6.75    14.826739  80.000000   10.366658
# 7 2014-01-01    Tomato      Clay     6.25    18.323272  80.000000    8.198084
#
#       n     p     k  crop_yield  soil_quality
# 1  84.0  66.0  50.0  104.871310     66.666667
# 3  50.0  40.0  30.0   58.939796     35.000000
# 4  49.5  45.0  38.5   32.970413     22.166667
# 5  55.0  44.0  36.0   29.356115     39.375000
# 7  60.0  45.0  40.0   22.221375     42.291667

# %% [markdown]
# <h2 id="binning">Binning</h2>
# <b>Why binning?</b>
# <p>
#     Binning is a process of transforming continuous numerical variables into discrete categorical 'bins' for grouped analysis.
# </p>

# %% [markdown]
# Let's plot the histogram of pH to see what the distribution of pH looks like.

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['soil_ph'])
plt.pyplot.xlabel('pH')
plt.pyplot.ylabel('Count')
plt.pyplot.title('pH binns')
# Out:
# Text(0.5, 1.0, 'pH binns')

# %% [markdown]
# <p>I would like 3 bins of equal size bandwidth so I use numpy's <code>linspace(start_value, end_value, numbers_generated</code> function.</p>
# <p>Since I want to include the minimum value of horsepower, I want to set start_value = min(df["ph"]).</p>
# <p>Since I want to include the maximum value of horsepower, I want to set end_value = max(df["ph"]).</p>
# <p>Since I am building 3 bins of equal length, there should be 4 dividers, so numbers_generated = 4.</p>

# %% [markdown]
# I build a bin array with a minimum value to a maximum value by using the bandwidth calculated above. The values will determine when one bin ends and another begins

# %%
binns=np.linspace(min(df['soil_ph']),max(df['soil_ph']),4)
binns
# Out:
# array([5.5       , 6.33333333, 7.16666667, 8.        ])

# %% [markdown]
# I set group names:

# %%
group_names=['Low','Medium','High']

# %% [markdown]
# I apply the function "cut" to determine what each value of `df['ph']` belongs to.

# %%
df['pH_Binned']=pd.cut(df['soil_ph'],binns, labels=group_names, include_lowest=True)
df[['soil_ph','pH_Binned']].head(10)
# Out:
#     soil_ph pH_Binned
# 1      6.50    Medium
# 3      6.75    Medium
# 4      5.50       Low
# 5      6.75    Medium
# 7      6.25       Low
# 8      5.50       Low
# 9      6.50    Medium
# 10     5.50       Low
# 11     6.25       Low
# 13     8.00      High

# %% [markdown]
# Let's see the number of vehicles in each bin:

# %%
df['pH_Binned'].value_counts()
# Out:
# pH_Binned
# Low       10238
# Medium    10128
# High       5129
# Name: count, dtype: int64

# %% [markdown]
# Let's plot the distribution of each bin:

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names,df['pH_Binned'].value_counts())
plt.pyplot.xlabel('pH')
plt.pyplot.ylabel('Count')
plt.pyplot.title('pH binns')
# Out:
# Text(0.5, 1.0, 'pH binns')

# %% [markdown]
# <p>
#     Look at the dataframe above carefully. You will find that the last column provides the bins for "ph" based on 3 categories ("Low", "Medium" and "High").
# </p>
# <p>
#     I successfully narrowed down the intervals from 59 to 3!
# </p>

# %% [markdown]
# Same instruction followed to create soil quality binns

# %%
binns=np.linspace(min(df['soil_quality']),max(df['soil_quality']),4)
binns
# Out:
# array([13.29166667, 33.63888889, 53.98611111, 74.33333333])

# %%
group_names=['Low','Medium','High']

# %%
df['soil_quality_Binned']=pd.cut(df['soil_quality'],binns, labels=group_names, include_lowest=True)
df[['soil_quality','soil_quality_Binned']].head(10)
# Out:
#     soil_quality soil_quality_Binned
# 1      66.666667                High
# 3      35.000000              Medium
# 4      22.166667                 Low
# 5      39.375000              Medium
# 7      42.291667              Medium
# 8      22.833333                 Low
# 9      63.666667                High
# 10     22.833333                 Low
# 11     48.708333              Medium
# 13     13.750000                 Low

# %%
df['soil_quality_Binned'].value_counts()
# Out:
# soil_quality_Binned
# Low       10244
# Medium     9657
# High       5594
# Name: count, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names,df['soil_quality_Binned'].value_counts())
plt.pyplot.xlabel('soil_quality')
plt.pyplot.ylabel('Count')
plt.pyplot.title('soil quality binns')
# Out:
# Text(0.5, 1.0, 'soil quality binns')

# %% [markdown]
# <p>
#     Look at the dataframe above carefully. I will find that the last column provides the bins for "soil quality" based on 3 categories ("Low", "Medium" and "High").
# </p>

# %% [markdown]
# <h2 id="pattern_visualization"> Analyzing Individual Feature Patterns Using Visualization</h2>

# %% [markdown]
# To install Seaborn we use pip, the Python package manager.

# %% [markdown]
# Import visualization packages "Matplotlib" and "Seaborn". Don't forget about "%matplotlib inline" to plot in a Jupyter notebook.

# %% [markdown]
# How to choose the right visualization method?
# When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help me find the right visualization method for that variable.

# %%
print(df.dtypes)
# Out:
# date                   datetime64[ns]
# crop_type                      object
# soil_type                      object
# soil_ph                       float64
# temperature                   float64
# humidity                      float64
# wind_speed                    float64
# n                             float64
# p                             float64
# k                             float64
# crop_yield                    float64
# soil_quality                  float64
# pH_Binned                    category
# soil_quality_Binned          category
# dtype: object

# %% [markdown]
# For example, I can calculate the correlation between variables of type "int64" or "float64" using the method "corr":

# %%
df.corr(numeric_only=True)
# Out:
#                soil_ph  temperature  humidity  wind_speed         n         p  \
# soil_ph       1.000000     0.004572 -0.003950   -0.000297  0.245892  0.292987
# temperature   0.004572     1.000000 -0.920010   -0.006783  0.104606  0.041853
# humidity     -0.003950    -0.920010  1.000000    0.005935 -0.099781 -0.041321
# wind_speed   -0.000297    -0.006783  0.005935    1.000000 -0.004962  0.000710
# n             0.245892     0.104606 -0.099781   -0.004962  1.000000  0.892536
# p             0.292987     0.041853 -0.041321    0.000710  0.892536  1.000000
# k             0.302229     0.040768 -0.039376   -0.000675  0.701191  0.906249
# crop_yield   -0.022309    -0.042079  0.295409   -0.003790  0.236137  0.274900
# soil_quality -0.322759     0.018189 -0.015412   -0.006329  0.358932  0.388352
#
#                      k  crop_yield  soil_quality
# soil_ph       0.302229   -0.022309     -0.322759
# temperature   0.040768   -0.042079      0.018189
# ...

# %% [markdown]
# The diagonal elements are always one; I will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the crop yield, I can use "regplot" which plots the scatterplot plus the fitted regression line for the data.</p>

# %% [markdown]
# Let's see several examples of different linear relationships:

# %% [markdown]
# <h3>Positive Linear Relationship</h4>

# %% [markdown]
# Let's find the scatterplot of "n" and "crop yield".

# %%
sns.regplot(x='n',y='crop_yield',data=df)
# Out:
# <Axes: xlabel='n', ylabel='crop_yield'>

# %% [markdown]
# <p>As the n goes up, the crop yield goes up: this indicates a positive direct correlation between these two variables. N seems like a pretty good predictor of crop yield since the regression line is almost a perfect diagonal line.</p>

# %% [markdown]
# I can examine the correlation between 'n' and 'crop yield' and see that it's approximately 0.2361.

# %%
df[['n','crop_yield']].corr(numeric_only=True)
# Out:
#                    n  crop_yield
# n           1.000000    0.236137
# crop_yield  0.236137    1.000000

# %% [markdown]
# Humidity is a potential predictor variable of crop yield. Let's find the scatterplot of "humidity" and "crop yield".

# %%
sns.regplot(x='humidity',y='crop_yield',data=df)
# Out:
# <Axes: xlabel='humidity', ylabel='crop_yield'>

# %% [markdown]
# As the humidity goes up, the crop yield goes up: this indicates a positive direct correlation between these two variables. Humidity seems like a pretty good predictor of crop yield since the regression line is almost a perfect diagonal line.

# %% [markdown]
# I can examine the correlation between 'humidity' and 'crop yield' and see that it's approximately 0.2954.

# %%
df[['humidity','crop_yield']].corr()
# Out:
#             humidity  crop_yield
# humidity    1.000000    0.295409
# crop_yield  0.295409    1.000000

# %%
sns.regplot(x='temperature',y='crop_yield',data=df)
# Out:
# <Axes: xlabel='temperature', ylabel='crop_yield'>

# %% [markdown]
# As temperature goes up, the crop yield goes down: this indicates an inverse/negative relationship between these two variables. Temperature could potentially be a predictor of crop yield.

# %% [markdown]
# I can examine the correlation between 'temperature' and 'crop yield' and see it's approximately -0.0420.

# %%
df[['temperature','crop_yield']].corr()
# Out:
#              temperature  crop_yield
# temperature     1.000000   -0.042079
# crop_yield     -0.042079    1.000000

# %% [markdown]
# <h3>Weak Linear Relationship</h3>

# %% [markdown]
# Let's see if "wind speed" is a predictor variable of "crop yield".

# %%
sns.regplot(x='wind_speed',y='crop_yield',data=df)
# Out:
# <Axes: xlabel='wind_speed', ylabel='crop_yield'>

# %% [markdown]
# Wind speed does not seem like a good predictor of the crop yield at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.

# %% [markdown]
# I can examine the correlation between 'wind speed' and 'crop yield' and see it's approximately --0.00379

# %%
df[['wind_speed','crop_yield']].corr()
# Out:
#             wind_speed  crop_yield
# wind_speed     1.00000    -0.00379
# crop_yield    -0.00379     1.00000

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %%
sns.boxplot(x='pH_Binned',y='crop_yield',data=df,color='purple')
# Out:
# <Axes: xlabel='pH_Binned', ylabel='crop_yield'>

# %% [markdown]
# <p>I see that the distributions of crop yield between the different soil_ph categories have a significant overlap, so I see that medium ph is the responsible for good crop yield. Let's examine engine "soil_quality" and "crop yield":

# %%
sns.boxplot(x='soil_quality_Binned',y='crop_yield',data=df,color='Blue')
# Out:
# <Axes: xlabel='soil_quality_Binned', ylabel='crop_yield'>

# %% [markdown]
# Here I see that the distribution of crop yield between these three soil quality categories, are distinct enough to take soil quality as a potential good predictor of crop yield.

# %%
sns.boxplot(x='soil_type',y='crop_yield',data=df,color='green')
# Out:
# <Axes: xlabel='soil_type', ylabel='crop_yield'>

# %% [markdown]
# Here I see that Loamy soil is the best for crop yield next is in clay soil. So I say that soil type is the slightly good predictor for crop yield.

# %%
sns.barplot(x='soil_type',y='crop_type', data=df)
# Out:
# <Axes: xlabel='soil_type', ylabel='crop_type'>

# %% [markdown]
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
#
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %% [markdown]
# I can apply the method "describe" as follows:

# %%
df.describe()
# Out:
#                                 date      soil_ph   temperature      humidity  \
# count                          25495  25495.00000  25495.000000  25495.000000
# mean   2019-01-01 12:38:32.924102912      6.60051     21.487087     76.926951
# min              2014-01-01 00:00:00      5.50000     10.000340     65.004056
# 25%              2016-06-03 00:00:00      6.25000     17.322668     74.458652
# 50%              2019-01-03 00:00:00      6.50000     21.328478     78.671522
# 75%              2021-06-13 12:00:00      6.75000     25.541348     80.000000
# max              2023-12-31 00:00:00      8.00000     34.995944     80.000000
# std                              NaN      0.81741      5.499282      3.764779
#
#          wind_speed             n             p             k    crop_yield  \
# count  25495.000000  25495.000000  25495.000000  25495.000000  25495.000000
# mean      10.002469     66.011649     53.010492     42.017062     38.501749
# ...

# %% [markdown]
# The default setting of "describe" skips variables of type object. I can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])
# Out:
#        crop_type soil_type
# count      25495     25495
# unique        10         5
# top         Rice    Saline
# freq        2569      5129

# %% [markdown]
# <h3>Value Counts</h3>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable I have. I can apply the "value_counts" method on the column "soil_type". Don’t forget the method "value_counts" only works on pandas series, not pandas dataframes. As a result, I only include one bracket <code>df['soil_type']</code>, not two brackets <code>df[['soil_type']]</code>.</p>

# %% [markdown]
# I can convert the series to a dataframe as follows:

# %%
df['soil_type'].value_counts().to_frame()
# Out:
#            count
# soil_type
# Saline      5129
# Clay        5123
# Peaty       5115
# Loamy       5069
# Sandy       5059

# %% [markdown]
# Let's repeat the above steps but save the results to the dataframe "soil_type_counts" and rename the column 'soil_type' to 'value_counts'.

# %%
soil_type_value_counts=df['soil_type'].value_counts().to_frame()
soil_type_value_counts.rename(columns={'soil_type': 'value_counts'},inplace=True)
soil_type_value_counts.index.name='soil_type'
soil_type_value_counts
# Out:
#            count
# soil_type
# Saline      5129
# Clay        5123
# Peaty       5115
# Loamy       5069
# Sandy       5059

# %%
crop_type_value_counts=df['crop_type'].value_counts().to_frame()
crop_type_value_counts.rename(columns={'crop_type': 'value_counts'},inplace=True)
crop_type_value_counts.index.name='crop_type'
crop_type_value_counts
# Out:
#            count
# crop_type
# Rice        2569
# Tomato      2566
# Soybean     2565
# Potato      2559
# Sugarcane   2556
# Wheat       2547
# Sunflower   2547
# Cotton      2541
# Corn        2524
# Barley      2521

# %% [markdown]
# <h2 id="basic_grouping">4. Basics of Grouping</h2>

# %% [markdown]
# <p>The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.</p>
#
# <p>For example, let's group by the variable "soil_type". I see that there are 5 different categories of soil_type.</p>

# %%
df['soil_type'].unique()
# Out:
# array(['Loamy', 'Sandy', 'Peaty', 'Clay', 'Saline'], dtype=object)

# %% [markdown]
# <p>If I want to know, on average, which type of drive wheel is most valuable, I can group "soil_type" and then average them.</p>
#
# <p>I can select the columns 'soil_type', 'soil_quality' ,'n', 'p', and 'crop_yield', then assign it to the variable "df_group_one".</p>

# %%
df_group_one=df[['soil_type','n','p','soil_quality','crop_yield']]

# %% [markdown]
# I can then calculate the average crop for each of the different categories of data.

# %%
df_group_one1=df_group_one.groupby(['soil_type'],as_index=False).mean()
df_group_one1
# Out:
#   soil_type          n          p  soil_quality  crop_yield
# 0      Clay  66.007027  52.986531     46.962034   41.607553
# 1     Loamy  76.961334  63.622016     64.380022   52.511372
# 2     Peaty  60.643011  47.807331     24.206386   31.327580
# 3    Saline  71.536752  58.304933     14.758847   33.733142
# 4     Sandy  54.871516  42.295315     37.504909   33.407508

# %% [markdown]
# <p>From our data, it seems Clay, Loamy are, on high, while peaty and sandy are approximately the same in crop_yield.</p>
#
# <p>I can also group by multiple variables. For example, let's group by both 'crop_type' and 'soil_type'. This groups the dataframe by the unique combination of 'crop_type' and 'soil_type'. I can store the results in the variable 'grouped_test1'.</p>

# %%
df_gptest = df[['soil_type','crop_type','crop_yield']]
grouped_test1 = df_gptest.groupby(['crop_type','soil_type'],as_index=False).mean()
grouped_test1
# Out:
#     crop_type soil_type  crop_yield
# 0      Barley      Clay   40.267307
# 1      Barley     Loamy   49.490742
# 2      Barley     Peaty   29.689464
# 3      Barley    Saline   32.693673
# 4      Barley     Sandy   31.965066
# 5        Corn      Clay   42.939212
# 6        Corn     Loamy   56.502231
# 7        Corn     Peaty   32.596639
# 8        Corn    Saline   37.266497
# 9        Corn     Sandy   35.432936
# 10     Cotton      Clay   45.800406
# 11     Cotton     Loamy   55.381060
# 12     Cotton     Peaty   34.588058
# 13     Cotton    Saline   36.283479
# 14     Cotton     Sandy   36.818702
# 15     Potato      Clay   42.619072
# 16     Potato     Loamy   49.266048
# 17     Potato     Peaty   31.042183
# 18     Potato    Saline   32.042370
# 19     Potato     Sandy   32.692683
# 20       Rice      Clay   43.143679
# 21       Rice     Loamy   56.845076
# 22       Rice     Peaty   33.287930
# 23       Rice    Saline   36.765415
# 24       Rice     Sandy   34.447300
# ...

# %% [markdown]
# <p>This grouped data is much easier to visualize when it is made into a pivot table. A pivot table is like an Excel spreadsheet, with one variable along the column and another along the row. I can convert the dataframe to a pivot table using the method "pivot" to create a pivot table from the groups.</p>
#
# <p>In this case, I will leave the crop_yield variable as the rows of the table, and pivot soil_type to become the columns of the table:</p>

# %%
grouped_pivot=df_group_one1.pivot(index='crop_yield',columns='soil_type')
grouped_pivot
# Out:
#                     n                                                      p  \
# soil_type        Clay      Loamy      Peaty     Saline      Sandy       Clay
# crop_yield
# 31.327580         NaN        NaN  60.643011        NaN        NaN        NaN
# 33.407508         NaN        NaN        NaN        NaN  54.871516        NaN
# 33.733142         NaN        NaN        NaN  71.536752        NaN        NaN
# 41.607553   66.007027        NaN        NaN        NaN        NaN  52.986531
# 52.511372         NaN  76.961334        NaN        NaN        NaN        NaN
#
#                                                        soil_quality  \
# soil_type       Loamy      Peaty     Saline      Sandy         Clay
# crop_yield
# 31.327580         NaN  47.807331        NaN        NaN          NaN
# 33.407508         NaN        NaN        NaN  42.295315          NaN
# 33.733142         NaN        NaN  58.304933        NaN          NaN
# ...

# %% [markdown]
# <p>Often, I won't have data for some of the pivot cells. I can fill these missing cells with the value 0, but any other value could potentially be used as well. It should be mentioned that missing data is quite a complex subject and is an entire course on its own.</p>

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                     n                                                      p  \
# soil_type        Clay      Loamy      Peaty     Saline      Sandy       Clay
# crop_yield
# 31.327580    0.000000   0.000000  60.643011   0.000000   0.000000   0.000000
# 33.407508    0.000000   0.000000   0.000000   0.000000  54.871516   0.000000
# 33.733142    0.000000   0.000000   0.000000  71.536752   0.000000   0.000000
# 41.607553   66.007027   0.000000   0.000000   0.000000   0.000000  52.986531
# 52.511372    0.000000  76.961334   0.000000   0.000000   0.000000   0.000000
#
#                                                        soil_quality  \
# soil_type       Loamy      Peaty     Saline      Sandy         Clay
# crop_yield
# 31.327580    0.000000  47.807331   0.000000   0.000000     0.000000
# 33.407508    0.000000   0.000000   0.000000  42.295315     0.000000
# 33.733142    0.000000   0.000000  58.304933   0.000000     0.000000
# ...

# %% [markdown]
#  Import "pyplot" as plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h4>Variables: Soil type  and crop type vs. crop yield</h4>

# %% [markdown]
# Let's use a heat map to visualize the relationship between crop type vs crop yield.

# %%
plt.pcolor(grouped_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# <p>The heatmap plots the target variable (crop yield) proportional to colour with respect to the variables 'soil type' and 'crop type' on the vertical and horizontal axis, respectively. This allows us to visualize how the crop yiled is related to 'soil type' and 'crop type'.</p>
#
# <p>The default labels convey no useful information to us. Let's change that:</p>

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(grouped_pivot, cmap='RdBu', annot=False) # Set annot=True to see numbers

plt.show()

# %% [markdown]
# <p>Visualization is very important in data science, and Python visualization packages provide great freedom.
#
# <p>The main question I want to answer in this module is, "What are the main characteristics which have the most impact on the crop yield?".</p>
#
# <p>To get a better measure of the important characteristics, I look at the correlation of these variables with the crop yield. In other words: how is the crop yield dependent on this variable?</p>

# %% [markdown]
# <h2 id="correlation_causation">5. Correlation and Causation</h2>

# %% [markdown]
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.</p>
#
# <p><b>Causation</b>: the relationship between cause and effect between two variables.</p>
#
# <p>It is important to know the difference between these two. Correlation does not imply causation. Determining correlation is much simpler  the determining causation as causation may require independent experimentation.</p>

# %% [markdown]
# <p><b>Pearson Correlation</b></p>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Perfect positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Perfect negative linear correlation.</li>
# </ul>

# %% [markdown]
# <p>Pearson Correlation is the default method of the function "corr". Like before, I can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
df.corr(numeric_only=True)
# Out:
#                soil_ph  temperature  humidity  wind_speed         n         p  \
# soil_ph       1.000000     0.004572 -0.003950   -0.000297  0.245892  0.292987
# temperature   0.004572     1.000000 -0.920010   -0.006783  0.104606  0.041853
# humidity     -0.003950    -0.920010  1.000000    0.005935 -0.099781 -0.041321
# wind_speed   -0.000297    -0.006783  0.005935    1.000000 -0.004962  0.000710
# n             0.245892     0.104606 -0.099781   -0.004962  1.000000  0.892536
# p             0.292987     0.041853 -0.041321    0.000710  0.892536  1.000000
# k             0.302229     0.040768 -0.039376   -0.000675  0.701191  0.906249
# crop_yield   -0.022309    -0.042079  0.295409   -0.003790  0.236137  0.274900
# soil_quality -0.322759     0.018189 -0.015412   -0.006329  0.358932  0.388352
#
#                      k  crop_yield  soil_quality
# soil_ph       0.302229   -0.022309     -0.322759
# temperature   0.040768   -0.042079      0.018189
# ...

# %% [markdown]
# Sometimes I would like to know the significant of the correlation estimate.

# %% [markdown]
# <b>P-value</b>
#
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally,I choose a significance level of 0.05, which means that I am 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
#
# <ul>
#     <li>p-value is $<$ 0.001: I say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %% [markdown]
# I can obtain this information using  "stats" module in the "scipy"  library.

# %%
from scipy import stats

# %% [markdown]
# <h3>Temperature vs. crop yield</h3>

# %% [markdown]
# Let's calculate the Pearson Correlation Coefficient and P-value of 'temperature' and 'crop yield'.

# %%
pearson_coef,p_value=stats.pearsonr(df['temperature'],df['crop_yield'])
print('The pearson corelation coefficient is:',pearson_coef,'with the P_value of p:',p_value)
# Out:
# The pearson corelation coefficient is: -0.042078833121898834 with the P_value of p: 1.799380571267212e-11

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between temperature and crop yield is statistically significant, although the linear relationship is negative (-0.0420788).</p>

# %% [markdown]
# <h3>Humidity vs. crop yield</h3>

# %% [markdown]
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'humidity' and 'crop yield'.

# %%
pearson_coef,p_value=stats.pearsonr(df['humidity'],df['crop_yield'])
print('The pearson correlation coefficient is:',pearson_coef, 'with the P_value of p:',p_value)
# Out:
# The pearson correlation coefficient is: 0.29540918168404656 with the P_value of p: 0.0

# %% [markdown]
# <h4>Conclusion:</h4>
#
# <p>Since the p-value is $<$ 0.001, the correlation between humidity and crop yield is statistically significant, and the linear relationship is not extremely strong (~0.2954).</p>

# %% [markdown]
# <h3>N vs. crop yield</h3>
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'n' and 'crop yield'.

# %%
pearson_coef,p_value=stats.pearsonr(df['n'],df['crop_yield'])
print('The pearson correlation coefficient is:',pearson_coef, 'with the P_value of p:',p_value)
# Out:
# The pearson correlation coefficient is: 0.23613650240698558 with the P_value of p: 5.1333e-320

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is $<$ 0.001, the correlation between n and crop yield is statistically significant, and the linear relationship is not extremely strong (~0.2361).</p>

# %% [markdown]
# <h3>P vs. crop yield</h3>
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'p' and 'crop yield'.

# %%
pearson_coef,p_value=stats.pearsonr(df['p'],df['crop_yield'])
print('The pearson correlation coefficient is:',pearson_coef, 'with the P_value of p:',p_value)
# Out:
# The pearson correlation coefficient is: 0.2749000772915891 with the P_value of p: 0.0

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is 0, the correlation between p and crop yield is statistically significant, and the linear relationship is not extremely strong (~0.2749).</p>

# %% [markdown]
# <h3>soil quality vs. crop yield</h3>
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'soil quality' and 'crop yield'.

# %%
pearson_coef,p_value=stats.pearsonr(df['soil_quality'],df['crop_yield'])
print('The pearson correlation coefficient is:',pearson_coef, 'with the P_value of p:',p_value)
# Out:
# The pearson correlation coefficient is: 0.32623667611669416 with the P_value of p: 0.0

# %% [markdown]
# <h4>Conclusion:</h4>
# <p>Since the p-value is 0, the correlation between soil quality and crop yield is statistically significant, and the linear relationship is not  strong (~0.3262) but greater than other varibles.</p>

# %% [markdown]
# <h2 id="anova">6. ANOVA</h2>

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant my calculated score value is.</p>
#
# <p>If my crop yield variable is strongly correlated with the variable I am analyzing, I expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %%
from scipy.stats import f_oneway

# %%
wheat=df[df['crop_type']=='Wheat']['crop_yield']
rice=df[df['crop_type']=='Rice']['crop_yield']
barley=df[df['crop_type']=='Barley']['crop_yield']
corn=df[df['crop_type']=='Corn']['crop_yield']
soybean=df[df['crop_type']=='Soybean']['crop_yield']

# %% [markdown]
# I can use the function 'f_oneway' in the module 'stats' to obtain the <b>F-test score</b> and <b>P-value</b>.

# %%
f_stat, p_value = f_oneway(barley,corn)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 42.03254753401548
# P-value: 9.833927599386756e-11

# %% [markdown]
# This is a great result with a moderate F-test score showing a strong correlation and a P-value of almost 0 implying almost certain statistical significance. But does this mean all tested groups are all this highly correlated?
#
# Let's examine them separately.

# %%
f_stat, p_value = f_oneway(rice,wheat)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 31.836051950851786
# P-value: 1.767755795244051e-08

# %% [markdown]
# Let's examine the other groups.

# %%
f_stat, p_value = f_oneway(wheat,soybean)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 0.09161632147341789
# P-value: 0.7621446268094056

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>Now, I have a better idea of what my data looks like and which variables are important to take into account when predicting the crop yield. I have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
#
# <ul>
#     <li>Soil_quality</li>
#     <li>Humidity</li>
#     <li>N</li>
#     <li>P</li>
#     <li>K</li>
#     <li>Temperature</li>
#     <li>Soil_pH</li>
#
# </ul>
#
# Categorical variables:
#
# <ul>
#     <li>Soil_type</li>
# </ul>
#
# <p>As I now move into building machine learning models to automate my analysis, feeding the model with variables that meaningfully affect my target variable will improve my model's prediction performance.</p>

# %% [markdown]
# # Model Development
#
# ## Objectives
#
# After completing this I will be able to:
#
# *   Develop prediction models

# %% [markdown]
# <p>In this section, I will develop several models that will predict the yield of the crop using the variables or features. This is just an estimate but should give me an objective idea of how much the crop should yield.</p>

# %% [markdown]
# <p>In data analytics, I often use <b>Model Development</b> to help me predict future observations from the data I have.</p>
#
# <p>A model will help me understand the exact relationship between different variables and how these variables are used to predict the result.</p>

# %% [markdown]
# <h2>1. Linear Regression and Multiple Linear Regression</h2>

# %% [markdown]
# <h3>Linear Regression</h3>

# %% [markdown]
# One example of a Data Model that I will be using is:
#
# Simple Linear Regression
# Simple Linear Regression is a method to help me understand the relationship between two variables:
#
# The predictor/independent variable (X)
# The response/dependent variable (that I want to predict)(Y)
# The result of Linear Regression is a linear function that predicts the response (dependent) variable as a function of the predictor (independent) variable.

# %% [markdown]
# <h4>Let's load the modules for linear regression:</h4>

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Create the linear regression object:

# %%
lm=LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# How could "soil quality" help us predict crop yield ?

# %% [markdown]
# For this example, I want to look at how soil quality can help me predict crop yield. Using simple linear regression, I will create a linear function with "soil quality" as the predictor variable and the "crop yield" as the response variable.

# %%
X=df[['soil_quality']]
Y=df['crop_yield']

# %% [markdown]
# Fit the linear model using highway-mpg:

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# I can output a prediction:

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([50.53619704, 37.46816017, 32.17216628, 39.27361263, 40.4772476 ])

# %% [markdown]
# What is the value of the intercept (a)?

# %%
lm.intercept_
# Out:
# np.float64(23.024540471584537)

# %% [markdown]
# What is the value of the slope (b)?

# %%
lm.coef_
# Out:
# array([0.41267485])

# %% [markdown]
# Another variable tru with same instruction

# %%
x=df[['p']]
y=df['crop_yield']
lm.fit(x,y)
lm.intercept_
# Out:
# np.float64(1.4801146865938506)

# %%
lm.coef_
# Out:
# array([0.69838314])

# %% [markdown]
# <h4>Multiple Linear Regression</h4>

# %% [markdown]
# What if I want to predict crop yield using more than one variable?
#
# If I want to use more variables in my model to predict crop yield, I can use Multiple Linear Regression. Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and two or more predictor (independent) variables. Most of the real-world regression models involve multiple predictors. I will illustrate the structure by using five predictor variables, but these results can generalize to any integer:

# %% [markdown]
# From the previous section I know that other good predictors of crop yield could be:
#
# Soil quality
# Humidity
# Temperature
# P
# K
# Soil pH
# Let's develop a model using these variables as the predictor variables.

# %%
Z=df[['soil_quality','humidity','temperature','p','k','soil_ph']]

# %% [markdown]
# Fit the linear model using the four above-mentioned variables.

# %%
lm.fit(Z,df['crop_yield'])
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(Z)
Yhat[0:5]
# Out:
# array([75.14084064, 51.8312799 , 27.85384292, 25.41899734, 47.99606888])

# %% [markdown]
# What is the value of the intercept(a)?

# %%
lm.intercept_
# Out:
# np.float64(-894.2782284827359)

# %% [markdown]
# What are the values of the coefficients (b1, b2, b3, b4)?

# %%
lm.coef_
# Out:
# array([0.32553241, 9.94898668, 6.04479819, 0.41896127, 0.04316001,
#        0.19966683])

# %% [markdown]
# <h2>2. Model Evaluation Using Visualization</h2>

# %% [markdown]
# Now that I've developed some models, how do I evaluate my models and choose the best one? One way to do this is by using a visualization.

# %% [markdown]
# Import the visualization package, seaborn:

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>Regression Plot</h3>

# %% [markdown]
# When it comes to simple linear regression, an excellent way to visualize the fit of my model is by using regression plots.
#
# This plot will show a combination of a scattered data points (a scatterplot), as well as the fitted linear regression line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).

# %% [markdown]
# Let's visualize humidity as potential predictor variable of crop yield:

# %%
width=10
height=8
plt.figure(figsize=(width,height))
sns.regplot(x='humidity',y='crop_yield',data=df)
plt.ylim(0,)
# Out:
# (0.0, 143.54749272645)

# %% [markdown]
# I can see from this plot that crop yield is positively correlated to humidity since the regression slope is positive
#
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. If the data is too far off from the line, this linear model might not be the best model for this data.
#
# Let's compare this plot to the regression plot of "temperature".

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='temperature',y='crop_yield',data=df)
plt.ylim(0,)
# Out:
# (0.0, 143.54749272645)

# %% [markdown]
# Comparing the regression plot of "temperature" and "humidity", I see that the points for "humidity" are positively increases which indicate positive slope. The points for "temperature" have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the "temperature" increases.

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='n',y='crop_yield',data=df)
plt.ylim(0,)
# Out:
# (0.0, 143.54749272645)

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='p',y='crop_yield',data=df)
plt.ylim(0,)
# Out:
# (0.0, 143.54749272645)

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='soil_quality',y='crop_yield',data=df)
plt.ylim(0,)
# Out:
# (0.0, 143.54749272645)

# %% [markdown]
# Above three regression plot of n,p,soil quality are indicate similar type of nature which means slope is positive.

# %% [markdown]
# <h3>Residual Plot</h3>
# A good way to visualize the variance of the data is to use a residual plot.
#
# What is a residual?
#
# The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When I look at a regression plot, the residual is the distance from the data point to the fitted regression line.
#
# So what is a residual plot?
#
# A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.
#
# What do I pay attention to when looking at a residual plot?
#
# I look at the spread of the residuals:
#
# - If the points in a residual plot are randomly spread out around the x-axis, then a linear model is appropriate for the data.
#
# Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.

# %%
plt.figure(figsize=(width,height))
sns.residplot(x='soil_ph',y='crop_yield',data=df)
plt.show()

# %%
plt.figure(figsize=(width,height))
sns.residplot(x='wind_speed',y='crop_yield',data=df)
plt.show()

# %% [markdown]
# What is this plot telling us?
#
# I can see from this residual plot of soil pH and wind speed that the residuals are randomly spread around the x-axis, leading us to indicate that maybe a non-linear model is more appropriate for this data.

# %% [markdown]
# <h3>Multiple Linear Regression</h3>

# %% [markdown]
# How do I visualize a model for Multiple Linear Regression? This gets a bit more complicated because I can't visualize it with regression or residual plot.
#
# One way to look at the fit of the model is by looking at the distribution plot. I can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.

# %% [markdown]
# First, let's make a prediction:

# %%
Yhat=lm.predict(Z)

# %%
plt.figure(figsize=(width,height))
ax1=sns.distplot(df['crop_yield'], hist=False, color='r',label='Actual values')
sns.distplot(Yhat, hist=False,color='b',label='Fitted values',ax=ax1)
plt.show()
plt.close()
# Out:
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_17748\2894244626.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df['crop_yield'], hist=False, color='r',label='Actual values')
# C:\Users\RIAZ\AppData\Local\Temp\ipykernel_17748\2894244626.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# I can see that the fitted values are reasonably differ to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.

# %% [markdown]
# <h2>3. Polynomial Regression and Pipelines</h2>

# %% [markdown]
# Polynomial regression is a particular case of the general linear regression model or multiple linear regression models.
#
# I get non-linear relationships by squaring or setting higher-order terms of the predictor variables.

# %% [markdown]
# I saw earlier that a linear model did not provide the best fit while using "humidity" as the predictor variable. Let's see if I can try fitting a polynomial model to the data instead.

# %% [markdown]
# I will use the following function to plot the data:

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Yield ~ soil_quality')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Crop Yield')

    plt.show()
    plt.close()

# %% [markdown]
# Let's get the variables:

# %%
x=df['soil_quality']
y=df['crop_yield']

# %% [markdown]
# Let's fit the polynomial using the function polyfit, then use the function poly1d to display the polynomial function.

# %%
f= np.polyfit(x,y, 3)
p= np.poly1d(f)
print(p)
# Out:
#            3           2
# -0.000318 x + 0.04933 x - 1.821 x + 50.47

# %% [markdown]
# Let's plot the function:

# %%
PlotPolly(p,x,y,'crop_yield')

# %% [markdown]
# Let's get the another variables:

# %% [markdown]
# I can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function "hits" more of the data points.

# %%
x=df['humidity']
y=df['crop_yield']

# %%
f=np.polyfit(x,y,3)
p=np.poly1d(f)
PlotPolly(p,x,y,'soil_ph')

# %% [markdown]
# I can perform a polynomial transform on multiple features. First, I import the module:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# I create a PolynomialFeatures object of degree 2:

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %% [markdown]
# In the original data, there are 25495 samples and 5 features.

# %%
Z.shape
# Out:
# (25495, 6)

# %% [markdown]
# After the transformation, there are 25495 samples and 21 features.

# %%
Z_pr.shape
# Out:
# (25495, 28)

# %% [markdown]
# <h2>Pipeline</h2>

# %% [markdown]
# <p>Data Pipelines simplify the steps of processing the data. I use the module <b>Pipeline</b> to create a pipeline. I also use <b>StandardScaler</b> as a step in our pipeline.</p>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# I create the pipeline by creating a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=True)),('model',LinearRegression())]

# %% [markdown]
# I input the list as an argument to the pipeline constructor:

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %% [markdown]
# First, I convert the data type Z to type float to avoid conversion warnings that may appear as a result of StandardScaler taking float inputs.
#
# Then, I can normalize the data,  perform a transform and fit the model simultaneously.

# %%
Z=Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %% [markdown]
# Similarly, I can normalize the data, perform a transform and produce a prediction simultaneously.

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([82.47201881, 50.44016725, 26.1504601 , 26.5524388 ])

# %% [markdown]
# <h2>4. Measures for In-Sample Evaluation</h2>

# %% [markdown]
# <p>When evaluating my models, not only do I want to visualize the results, but I also want a quantitative measure to determine how accurate the model is.</p>
#
# <p>Two very important measures that are often used in Statistics to determine the accuracy of a model are:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared</b>
#
# <p>R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.</p>
#
# <b>Mean Squared Error (MSE)</b>
#
# <p>The Mean Squared Error measures the average of the squares of errors. That is, the difference between actual value (y) and the estimated value (ŷ).</p>

# %% [markdown]
# <h3>Model 1: Simple Linear Regression</h3>

# %% [markdown]
# Let's calculate the R^2:

# %%
lm.fit(X,Y)
print('The R-square value:', lm.score(X,Y))
# Out:
# The R-square value: 0.10643036884366897

# %% [markdown]
# I can say that ~10.64% of the variation of the price is explained by this simple linear model, which I have built using the humidity data.

# %% [markdown]
# Let's calculate the MSE:

# %% [markdown]
# I can predict the output i.e., "yhat" using the predict method, where X is the input variable:

# %%
Yhat=lm.predict(X)
print('The first four value of the predicted values:', Yhat[0:4])
# Out:
# The first four value of the predicted values: [50.53619704 37.46816017 32.17216628 39.27361263]

# %% [markdown]
# Let's import the function mean_squared_error from the module metrics:

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# I can compare the predicted results with the actual results:

# %%
mse=mean_squared_error(df['crop_yield'],Yhat)
print('The mean squared error of crop yield and predicted value:',mse)
# Out:
# The mean squared error of crop yield and predicted value: 448.20117705306876

# %% [markdown]
# <h3>Model 2: Multiple Linear Regression</h3>

# %% [markdown]
# Let's calculate the R^2:

# %%
lm.fit(Z,df['crop_yield'])
print('The Rsquared is:',lm.score(Z,df['crop_yield']))
# Out:
# The Rsquared is: 0.5649246530846318

# %% [markdown]
# I can say that ~56.4924 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# Let's calculate the MSE.

# %% [markdown]
# I produce a prediction:

# %%
Y_predict_multifit=lm.predict(Z)

# %% [markdown]
# I compare the predicted results with the actual results:

# %%
print('The mean squared error of crop yield and predicted value using multifit is:',\
mean_squared_error(df['crop_yield'],Y_predict_multifit))
# Out:
# The mean squared error of crop yield and predicted value using multifit is: 218.2272939847981

# %% [markdown]
# <h3>Model 3: Polynomial Fit</h3>

# %% [markdown]
# Let's calculate the R^2.

# %% [markdown]
# Let’s import the function r2_score from the module metrics as I are using a different function.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# I apply the function to get the value of R^2:

# %%
r_squared=r2_score(y,p(x))
print('The R square value:',r_squared)
# Out:
# The R square value: 0.23114507898454695

# %% [markdown]
# I can say that ~23.11 % of the variation of price is explained by this polynomial fit.

# %% [markdown]
# <h3>MSE</h3>

# %% [markdown]
# I can also calculate the MSE:

# %%
mean_squared_error(df['crop_yield'],p(x))
# Out:
# 385.64614168482393

# %% [markdown]
# <h2>5. Prediction and Decision Making</h2>
# <h3>Prediction</h3>
#
# <p>In the previous section, I trained the model using the method <b>fit</b>. Now I will use the method <b>predict</b> to produce a prediction. Lets import <b>pyplot</b> for plotting; I will also be using some functions from numpy.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Create a new input:

# %%
new_input=np.arange(1,100,1).reshape(-1,1)

# %% [markdown]
# Fit the model:

# %%
lm.fit(X,Y)
lm
# Out:
# LinearRegression()

# %% [markdown]
# Produce a prediction:

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# C:\Users\RIAZ\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.43721532, 23.84989017, 24.26256502, 24.67523987, 25.08791471])

# %% [markdown]
# I can plot the data:

# %%
plt.plot(new_input,yhat)
plt.show()

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>

# %% [markdown]
# Now that I have visualized the different models, and generated the R-squared and MSE values for the fits, how do I determine a good model fit?
#
# What is a good R-squared value?
# When comparing models, the model with the higher R-squared value is a better fit for the data.
#
# What is a good MSE?
# When comparing models, the model with the smallest MSE value is a better fit for the data.
#
# Let's take a look at the values for the different models.
# Simple Linear Regression: Using 'n' as a Predictor Variable of Crop yield.
#
# R-squared:0.10643036884366897
# MSE: 448.20117705306876
#
# Multiple Linear Regression: temperature,humidity,soil_quality,soil_ph,p,k as Predictor Variables of Crop yield.
#
# R-squared:  0.5649246530846318
# MSE: 218.2272939847981
#
# Polynomial Fit: Using 'n' as a Predictor Variable of Crop yield.
#
# R-squared: 0.23114507898454695
# MSE: 385.64614168482393

# %% [markdown]
# <h3>Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)</h3>

# %% [markdown]
# <p>Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, you should always check the MSE and R^2.</p>
#
# <p>In order to compare the results of the MLR vs SLR models, I look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
# <ul>
#     <li><b>MSE</b>: The MSE of SLR is  448.20117705306876  while MLR has an MSE of 218.2272939847981.  The MSE of MLR is much smaller.</li>
#     <li><b>R-squared</b>: In this case, I can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.1064) is very small compared to the R-squared for the MLR (~0.564924).</li>
# </ul>
# </p>
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs. Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: I can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, I can conclude that this was a better fit model than the simple linear regression for predicting "crop yield" with "soil_quality" as a predictor variable.</p>

# %% [markdown]
# <h3>Multiple Linear Regression (MLR) vs. Polynomial Fit</h3>

# %% [markdown]
# MSE: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.
#
# R-squared: The R-squared for the MLR is also much larger than for the Polynomial Fit.

# %% [markdown]
# <h2>Conclusion</h2>

# %% [markdown]
# Comparing these three models, I conclude that the MLR model is the best model to be able to predict crop yield from our dataset. This result makes sense since I have 10 variables in total and I know that more than one of those variables are potential predictors of the final crop yield.

# %% [markdown]
# <h2>Model Evaluation and Refinement</h2>

# %% [markdown]
# ## Objectives
#
# After completing this I will be able to:
#
# * Evaluate and refine prediction models

# %% [markdown]
# Libraries for plotting:

# %%
from ipywidgets import interact, interactive,fixed, interact_manual

# %% [markdown]
# <h2>Functions for Plotting</h2>

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Crop Yield (in ton per hectare)')
    plt.ylabel('Proportion of Crops material')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Crop Yield')
    plt.legend()

# %% [markdown]
# <h2 id="ref1">Training and Testing</h2>
#
# <p>An important step in testing my model is to split my data into training and testing data. I will place the target data <b>crop yield</b> in a separate dataframe <b>y_data</b>:</p>

# %%
y_data=df['crop_yield']

# %% [markdown]
# Drop price data in dataframe <b>x_data:</b>

# %%
x_data=df.drop('crop_yield',axis=1)

# %% [markdown]
# Now, I randomly split my data into training and testing data using the function train_test_split.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.10,random_state=1)
print('number of test samples:',x_test.shape[0])
print('number of train samples:',x_train.shape[0])
# Out:
# number of test samples: 2550
# number of train samples: 22945

# %% [markdown]
# The test_size parameter sets the proportion of data that is split into the testing set. In the above, the testing set is 10% of the total dataset.

# %% [markdown]
# Let's import LinearRegression from the module linear_model.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# I create a Linear Regression object:

# %%
lre=LinearRegression()

# %% [markdown]
# I fit the model using the feature "soil quality":

# %%
lre.fit(x_train[['soil_quality']],y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Let's calculate the R^2 on the test and training data:

# %%
lre.score(x_test[['soil_quality']],y_test)
# Out:
# 0.09885454398724458

# %%
lre.score(x_train[['soil_quality']],y_train)
# Out:
# 0.10727818348676088

# %% [markdown]
# I can see the R^2 is smaller using the test data compared to the training data.

# %% [markdown]
# <h2>Cross-Validation Score</h2>

# %% [markdown]
# Let's import cross_val_score from the module model_selection.

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# I input the object, the feature ("soil quality"), and the target data (y_data). The parameter 'cv' determines the number of folds. In this case, it is 4.

# %%
Rcross=cross_val_score(lre,x_data[['soil_quality']],y_data,cv=4)
Rcross
# Out:
# array([0.09628102, 0.10406086, 0.1103489 , 0.11324872])

# %% [markdown]
# The default scoring is R^2. Each element in the array has the average R^2 value for the fold:

# %% [markdown]
# I can calculate the average and standard deviation of my estimate:

# %%
print('The mean of the folds are:',Rcross.mean(),'and the standard deviation is:',Rcross.std())
# Out:
# The mean of the folds are: 0.10598487445175 and the standard deviation is: 0.0065129624555508

# %% [markdown]
# I can use negative squared error as a score by setting the parameter 'scoring' metric to 'neg_mean_squared_error'.

# %%
-1*cross_val_score(lre,x_data[['soil_quality']],y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([451.99315827, 439.59310591, 446.5535001 , 455.13143864])

# %% [markdown]
# I can also use the function 'cross_val_predict' to predict the output. The function splits up the data into the specified number of folds, with one fold for testing and the other folds are used for training. First, import the function:

# %%
from sklearn.model_selection import cross_val_predict

# %% [markdown]
# I input the object, the feature "soil_quality", and the target data y_data. The parameter 'cv' determines the number of folds. In this case, it is 4. I can produce an output:

# %%
yhat=cross_val_predict(lre,x_data[['soil_quality']],y_data,cv=4)
yhat[0:5]
# Out:
# array([50.85196876, 37.56872563, 32.18551657, 39.40391053, 40.62736714])

# %% [markdown]
# <h2 id="ref2">Overfitting, Underfitting and Model Selection</h2>
#
# It turns out that the test data, sometimes referred to as the "out of sample data", is a much better measure of how well your model performs in the real world. One reason for this is overfitting.
#
# Let's go over some examples. It turns out these differences are more apparent in Multiple Linear Regression and Polynomial Regression so we will explore overfitting in that context.

# %% [markdown]
# Let's create Multiple Linear Regression objects and train the model using 'temperature', 'soil_ph', 'humidity','soil_quality' 'k', and 'p' as features.

# %%
lr=LinearRegression()
lr.fit(x_train[['temperature','soil_ph','soil_quality','humidity','k','p']],y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction using training data:

# %%
yhat_train=lr.predict(x_train[['temperature','soil_ph','soil_quality','humidity','k','p']])
yhat_train[0:5]
# Out:
# array([25.50465215, 24.66275686, 23.99752498, 65.75092611, 39.9101637 ])

# %% [markdown]
# Prediction using test data:

# %%
yhat_test=lr.predict(x_test[['temperature','soil_ph','soil_quality','humidity','k','p']])
yhat_test[0:5]
# Out:
# array([56.30893019, 27.38371682, 57.20644289, 48.30493401, 46.62467563])

# %% [markdown]
# Let's perform some model evaluation using our training and testing data separately. First, we import the seaborn and matplotlib library for plotting.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Let's examine the distribution of the predicted values of the training data.

# %%
Title='Distribution plot of predicting value using trfaining data vs Training data distribution'
DistributionPlot(y_train,yhat_train,"Actual values(Train)","Predicted values(Train)",Title)

# %% [markdown]
# Figure 1: Plot of predicted values using the training data compared to the actual values of the training data.

# %% [markdown]
# So far, the model seems to be doing well in learning from the training dataset. But what happens when the model encounters new data from the testing dataset? When the model generates new values from the test data, we see the distribution of the predicted values is much different from the actual target values.

# %% [markdown]
# Let's examine the distribution of the predicted values of the test data.

# %%
Title='Distribution plot of predicting value using test data vs Test data distribution'
DistributionPlot(y_test,yhat_test,"Actual values(Test)","Predicted values(Test)",Title)

# %% [markdown]
# Figure 2: Plot of predicted value using the test data compared to the actual values of the test data.

# %% [markdown]
# Comparing Figure 1 and Figure 2, it is evident that the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent in the range of 20 to 60. This is where the shape of the distribution is extremely different. Let's see if polynomial regression also exhibits a drop in the prediction accuracy when analysing the test dataset.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# <h4>Overfitting</h4>
# Overfitting occurs when the model fits the noise, but not the underlying process. Therefore, when testing my model using the test set, my model does not perform as well since it is modelling noise, not the underlying process that generated the relationship. Let's create a degree 5 polynomial model.

# %% [markdown]
# Let's use 55 percent of the data for training and the rest for testing:

# %%
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.45,random_state=0)

# %% [markdown]
# I will perform a degree 5 polynomial transformation on the feature 'n'.

# %%
pr=PolynomialFeatures(degree=5)
xtrain_pr=pr.fit_transform(x_train[['soil_quality']])
xtest_pr=pr.fit_transform(x_test[['soil_quality']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %% [markdown]
# Now, let's create a Linear Regression model "poly" and train it.

# %%
poly=LinearRegression()
poly.fit(xtrain_pr,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# I can see the output of our model using the method "predict." I assign the values to "yhat".

# %%
yhat=poly.predict(xtest_pr)
yhat[0:5]
# Out:
# array([31.64727828, 32.47626503, 32.24678087, 33.07700031, 32.89665483])

# %% [markdown]
# Let's take the first five predicted values and compare it to the actual targets.

# %%
print('predicted values:',yhat[0:4])
print('True values:',y_test[0:4].values)
# Out:
# predicted values: [31.64727828 32.47626503 32.24678087 33.07700031]
# True values: [18.19835665 14.82468829  5.74220385 20.73513543]

# %% [markdown]
# I will use the function "PollyPlot" that I defined at the beginning of the lab to display the training data, testing data, and the predicted function.

# %%
PollyPlot(x_train['soil_quality'],x_test['soil_quality'],y_train,y_test,poly,pr)

# %% [markdown]
# Figure 3: A polynomial regression model where red dots represent training data, green dots represent test data, and the blue line represents the model prediction.

# %% [markdown]
# I see that the estimated function appears to track the data but around 90 horsepower, the function begins to diverge from the data points.

# %% [markdown]
# R^2 of the training data:

# %%
poly.score(xtrain_pr,y_train)
# Out:
# 0.12841622812198594

# %% [markdown]
# R^2 of the test data:

# %%
poly.score(xtest_pr,y_test)
# Out:
# 0.12548380353568422

# %% [markdown]
# I see the R^2 for the training data is 0.0565563 while the R^2 on the test data was 0.060338797. The lower the R^2, the worse the model. A negative R^2 is a sign of overfitting but here not see any overfitting.

# %% [markdown]
# Let's see how the R^2 changes on the test data for different order polynomials and then plot the results:

# %%
from sklearn.pipeline import make_pipeline

order = [1, 2, 3, 4]
Rsqu_test = []

for n in order:
    # Combine transformation and regression into one object
    model = make_pipeline(PolynomialFeatures(degree=n), LinearRegression())
    
    # Fit and score in two lines
    model.fit(x_train[['n']], y_train)
    Rsqu_test.append(model.score(x_test[['n']], y_test))

# Plotting
plt.plot(order, Rsqu_test)
plt.xlabel('Order')
plt.ylabel('$R^2$')
plt.show()

# %% [markdown]
# I see the R^2 gradually increases until an order two polynomial is used. Then, the R^2 straight until the three polynomial and then dramatically increases at an order four polynomial.

# %% [markdown]
# The following function will be used in the next section.

# %%
def f(order,test_data):
    x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.45,random_state=0)
    pr=PolynomialFeatures(degree=order)
    xtrain_pr=pr.fit_transform(x_train[['n']])
    xtest_pr=pr.fit_transform(x_test[['n']])
    poly=LinearRegression()
    poly.fit(xtrain_pr,y_train)
    PollyPlot(x_train['n'],x_test['n'],y_train,y_test,poly,pr)

# %% [markdown]
# The following interface allows to experiment with different polynomial orders and different amounts of data.

# %%
interact(f,order=(0,6,1),test_data=(0.05,0.95,0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %% [markdown]
# <h2 id="ref3">Ridge Regression</h2>

# %% [markdown]
# In this section, I will review Ridge Regression and see how the parameter alpha changes the model. Just a note, here my test data will be used as validation data.

# %% [markdown]
# Let's perform a degree two polynomial transformation on my data.

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['temperature','soil_ph','soil_quality','humidity','k','p']])
x_test_pr=pr.fit_transform(x_test[['temperature','soil_ph','soil_quality','humidity','k','p']])

# %% [markdown]
# Let's import Ridge from the module linear models.

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# Let's create a Ridge regression object, setting the regularization parameter (alpha) to 1

# %%
RidgeModel=Ridge(alpha=1)

# %% [markdown]
# Like regular regression, I can fit the model using the method fit.

# %%
RidgeModel.fit(x_train_pr,y_train)
# Out:
# Ridge(alpha=1)

# %% [markdown]
# Similarly, I can obtain a prediction:

# %%
yhat=RidgeModel.predict(x_test_pr)

# %% [markdown]
# Let's compare the first four predicted samples to my test set:

# %%
print('predicted',yhat[0:4])
print('test set',y_test[0:4].values)
# Out:
# predicted [28.28259384 25.55467644 -9.98088551 15.1871653 ]
# test set [18.19835665 14.82468829  5.74220385 20.73513543]

# %% [markdown]
# I select the value of alpha that minimizes the test error. To do so, I can use a for loop. I have also created a progress bar to see how many iterations I have completed so far.
#
# from tqdm import tqdm

# %%
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|██████████████████████████████████████████| 1000/1000 [00:17<00:00, 57.24it/s, Test Score=0.58, Train Score=0.573]

# %% [markdown]
# I can plot out the value of R^2 for different alphas:

# %%
width=12
height=10
plt.figure(figsize=(width,height))
plt.plot(Alpha,Rsqu_test,label='validation data')
plt.plot(Alpha,Rsqu_train,'r',label='Training data')
plt.xlabel('Alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# Figure 4: The blue line represents the R^2 of the validation data, and the red line represents the R^2 of the training data. The x-axis represents the different values of Alpha.

# %% [markdown]
# Here the model is built and tested on the same data, so the training and test data are the same.
#
# The red line in Figure 4 represents the R^2 of the training data. As alpha increases the R^2 increases. Therefore, as alpha increases, the model performs good on the training data
#
# The blue line represents the R^2 on the validation data. As the value for alpha increases, the R^2 increases and converges at a point.

# %% [markdown]
# <h2 id="ref4"> Grid Search</h2>

# %% [markdown]
# The term alpha is a hyperparameter. Sklearn has the class GridSearchCV to make the process of finding the best hyperparameter simpler.

# %% [markdown]
# Let's import GridSearchCV from the module model_selection.

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We create a dictionary of parameter values:

# %%
parameters1=[{'alpha':[0.001,0.1,1,10,100,1000,10000,100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000]}]

# %% [markdown]
# Create a Ridge regression object:

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %% [markdown]
# Create a ridge grid search object:

# %%
Grid1=GridSearchCV(RR,parameters1,cv=4)

# %% [markdown]
# In order to avoid a deprecation warning due to the iid parameter, I set the value of iid to "None".
#
# Fit the model:

# %%
Grid1.fit(x_data[['temperature','soil_ph','soil_quality','humidity','k','p']],y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000,
#                                     100000]}])

# %% [markdown]
# The object finds the best parameter values on the validation data. I can obtain the estimator with the best parameters and assign it to the variable BestRR as follows:

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10)

# %% [markdown]
# Now, I test our model on the test data:

# %%
BestRR.score(x_test[['temperature','soil_ph','soil_quality','humidity','k','p']],y_test)
# Out:
# 0.5698769055375605

# %%
BestRR.score(x_train[['temperature','soil_ph','soil_quality','humidity','k','p']],y_train)
# Out:
# 0.5608387055231155

# %% [markdown]
# <b>Complete the analysis</b>
